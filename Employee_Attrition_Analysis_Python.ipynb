# %%
import pandas as pd

# upload dataset
df = pd.read_csv('C:\\Users\\Administrator\\OneDrive - SNHU\\DAT223\\LLCP2017Dataset.csv')

# print rows and cols
shape = df.shape
print(f'rows={shape[0]},  cols={shape[1]} \n')

# create a list of important variables
# note: the step below is an example, you should include the variables that you have identified as being important
cols = ['IDATE', 'HLTHPLN1' ,'ASTHMA3' , 'ASTHNOW', 'SMOKE100' , 'SMOKDAY2', 'STOPSMK2']
df_subset = df[cols].copy()

# print first 10 rows
print(df_subset.head(10))
# Out:
# rows=3999,  cols=38
#
#      IDATE  HLTHPLN1  ASTHMA3  ASTHNOW  SMOKE100  SMOKDAY2  STOPSMK2
# 0  1302017         1        2      NaN       2.0       NaN       NaN
# 1  1122017         1        2      NaN       2.0       NaN       NaN
# 2  1102017         1        2      NaN       2.0       NaN       NaN
# 3  2082017         1        2      NaN       2.0       NaN       NaN
# 4  1302017         1        1      1.0       1.0       3.0       NaN
# 5  1302017         1        2      NaN       1.0       1.0       2.0
# 6  1052017         1        2      NaN       2.0       NaN       NaN
# 7  2022017         1        2      NaN       2.0       NaN       NaN
# 8  1242017         1        2      NaN       1.0       3.0       NaN
# 9  1122017         1        2      NaN       1.0       3.0       NaN
